# %%
import gensim

# %% [markdown]
# # Step1: prepare the corpus for training

# %%
# Step 1. 주어진 data로 gensim을 활용하여 word2vec 모델 학습

# 학습을 위한 데이터 로딩 -- Data 준비
class TextIterator(object):
	def __init__(self, fname):
		self.fname = fname

	def __iter__(self):
		for line in open(self.fname):
			yield line.split()

filename = 'newskor.txt'
sentences = TextIterator(filename)

# %% [markdown]
# # Step 2, 3: Training & Load Word2Vec model

# %%
# Hyperparams
train = True # train flag (True: train model / False: load trained model)
SIZE = 300 # vector size
WINDOW = 5 # context window
SG = 1 # 1 for skip-gram / otherwise cbow
MIN_COUNT = 10 # ignores all words appearing lower than min_count (10번 미만 데이터 학습 X.)
WORKERS = 20 # cpu cores

# %%
if train:
    model = gensim.models.Word2Vec(
        size=SIZE, window=WINDOW, sg=SG, 
        min_count=MIN_COUNT, workers=WORKERS
    )
    model.build_vocab(sentences) # prepare model vocab
    model.train(sentences, total_examples=model.corpus_count, epochs=5)
    model.save('newskor.model')
else:
    model = gensim.models.Word2Vec.load('newskor.model')

# %%
model.wv.index2word # See vocabs
# Out:
# ['하',
#  '이',
#  '.',
#  '는',
#  '을',
#  'ㄴ',
#  '다',
#  '의',
#  '에',
#  '를',
#  '은',
#  '어',
#  '있',
#  '고',
#  '으로',
#  '가',
#  '였',
#  'ㄹ',
#  '되',
#  ',',
#  '에서',
#  '었',
#  ')',
#  '(',
#  '로',
#  '것',
#  '도',
#  '등',
#  '과',
#  '들',
#  '지',
#  '와',
#  '여',
#  '일',
#  '기',
#  '·',
#  'ㄴ다',
#  '적',
#  '수',
#  '아',
#  '%',
#  '게',
#  '원',
#  '년',
#  '2',
#  '았',
#  '3',
#  '1',
#  '다고',
#  '“',
#  '”',
#  '월',
#  '위하',
#  '대하',
#  '말하',
#  '시장',
#  '면',
#  '업체',
#  '따르',
#  '하고',
#  '않',
#  '만',
#  '까지',
#  '‘',
#  '’',
#  '밝히',
#  '명',
#  '및',
#  '부터',
#  '다가',
#  '미국',
#  '며',
#  '이라고',
#  '4',
#  '개',
#  '대',
#  '나',
#  '오',
#  '대표',
#  '국내',
#  '한국',
#  '5',
#  '다는',
#  '던',
#  '서비스',
#  '습니다',
#  '개발',
#  '계획',
#  '인',
#  '주',
#  '통하',
#  '제품',
#  '없',
#  '또',
#  '화',
#  '정부',
#  '면서',
#  '최근',
#  '한',
#  '으며',
#  '6',
#  '지난해',
#  '중',
#  '그',
#  '사업',
#  '올해',
#  '중국',
#  '보이',
#  '크',
#  '받',
#  '일본',
#  '이번',
#  '10',
#  '보다',
#  '내',
#  '기업',
#  '경우',
#  '보',
#  '대통령',
#  '같',
#  '-',
#  '관련',
#  '기술',
#  '에게',
#  '지만',
#  '때문',
#  '전',
#  '전망',
#  'LG',
#  '라고',
#  '7',
#  '달러',
#  '현재',
#  '예정',
#  '지나',
#  '어서',
#  'ㄴ다는',
#  '특히',
#  '이상',
#  '8',
#  '북한',
#  '사',
#  '시스템',
#  '문제',
#  '김',
#  '삼성전자',
#  '겠',
#  '늘',
#  '간',
#  '나서',
#  '관계자',
#  '잇',
#  '9',
#  '아니',
#  '라는',
#  '용',
#  '인터넷',
#  '높',
#  '라',
#  '내년',
#  '솔루션',
#  '위',
#  '데',
#  '회사',
#  '시키',
#  '장비',
#  'ㅁ',
#  '씨',
#  '업계',
#  '이날',
#  '때',
#  '다면서',
#  '두',
#  '세계',
#  '도록',
#  '예상',
#  '추진',
#  '게임',
#  'PC',
#  '그러나',
#  '말',
#  '확대',
#  '한편',
#  '수출',
#  '공급',
#  '함께',
#  'ㄴ다고',
#  '전자',
#  '매출',
#  '구축',
#  '많',
#  '못하',
#  '점',
#  '으나',
#  '20',
#  '규모',
#  '투자',
#  '분야',
#  '이후',
#  'TV',
#  '서울',
#  'IT',
#  '가운데',
#  '지역',
#  '경기',
#  '세',
#  '뒤',
#  '시작',
#  'SK',
#  '사용',
#  '디지털',
#  '시',
#  '자',
#  '기존',
#  '지원',
#  '라면서',
#  '가격',
#  '단말기',
#  '이나',
#  '제공',
#  '정도',
#  '방침',
#  '어야',
#  'LCD',
#  '발표',
#  '본격',
#  '텔레콤',
#  '알리',
#  '11',
#  '30',
#  '분기',
#  '이르',
#  'ㅂ니다',
#  '12',
#  '노',
#  '확보',
#  '열리',
#  '가장',
#  '정보',
#  '조사',
#  '대상',
#  '기록',
#  '기대',
#  '출시',
#  '여야',
#  '가능성',
#  '판매',
#  '안',
#  '더',
#  '사장',
#  '가능',
#  '*',
#  '모두',
#  '도입',
#  '이용',
#  '다른',
#  '상황',
#  '기반',
#  '진출',
#  '강화',
#  '수준',
#  '갖',
#  '키',
#  '설명',
#  '앞',
#  '필요',
#  '증가',
#  '포함',
#  '휴대폰',
#  '결과',
#  '∼',
#  '해외',
#  '비하',
#  '기능',
#  '0',
#  '올',
#  '공동',
#  '후',
#  '15',
#  '차',
#  '전략',
#  '일부',
#  '지적',
#  '처음',
#  '분',
#  '방식',
#  '방안',
#  '반도체',
#  '마련',
#  '형',
#  '2000',
#  '주요',
#  '회',
#  '만들',
#  '는데',
#  '주장',
#  '결정',
#  '분석',
#  '생산',
#  '나오',
#  '요',
#  '전체',
#  '국가',
#  '당',
#  '나타나',
#  '통합',
#  '사업자',
#  '가지',
#  '관리',
#  '새롭',
#  '△',
#  '그동안',
#  '삼성',
#  '의원',
#  'KT',
#  '이라크',
#  '중심',
#  '미',
#  '참여',
#  '경쟁',
#  '우리',
#  '요구',
#  '장관',
#  'e',
#  '수요',
#  '이미',
#  '제',
#  '산업',
#  'D',
#  '추가',
#  '프로젝트',
#  '최대',
#  '각각',
#  '칩',
#  '내용',
#  '초',
#  '물론',
#  '다양',
#  '거나',
#  '서버',
#  '나가',
#  '시간',
#  '알',
#  '적용',
#  '전하',
#  '좋',
#  '오르',
#  '성장',
#  '벌이',
#  '상',
#  '약',
#  '50',
#  '16',
#  '실시',
#  '검찰',
#  '박',
#  '콘텐츠',
#  '네트워크',
#  '정책',
#  '마케팅',
#  '뿐',
#  '하지만',
#  '총',
#  '모바일',
#  '평가',
#  '대한',
#  '배',
#  '감독',
#  '하반기',
#  '부문',
#  '13',
#  '25',
#  '사람',
#  '선정',
#  '처럼',
#  '고객',
#  '향후',
#  '계속',
#  '활용',
#  '방송',
#  '들어가',
#  '14',
#  '듣',
#  '열',
#  '장',
#  '이란',
#  '계',
#  '온라인',
#  '경제',
#  '설립',
#  '만큼',
#  '"',
#  '17',
#  '사실',
#  '회장',
#  '대비',
#  '발생',
#  '자체',
#  '차세대',
#  '올리',
#  '상태',
#  '높이',
#  '적극',
#  '인하',
#  '한나라당',
#  '계약',
#  '성공',
#  '협력',
#  '차지',
#  '선보이',
#  '앞서',
#  '21',
#  '어렵',
#  '떨어지',
#  '진행',
#  '유럽',
#  '운영',
#  '18',
#  '개월',
#  '이루',
#  '목표',
#  '달',
#  '집중',
#  '보안',
#  '팀',
#  '상반기',
#  '관심',
#  '=',
#  '번',
#  '지난달',
#  '검토',
#  '작업',
#  '다시',
#  '협상',
#  '100',
#  '우려',
#  '자신',
#  '40',
#  '통신',
#  '소프트웨어',
#  '모든',
#  '하나',
#  '확인',
#  '인치',
#  '아직',
#  '그룹',
#  '더욱',
#  '동안',
#  '지금',
#  '공략',
#  '&',
#  '교수',
#  '직접',
#  '측',
#  '국민',
#  '기준',
#  '구성',
#  '대부분',
#  '곳',
#  '생각',
#  '코리아',
#  '놓',
#  '강조',
#  "'",
#  '24',
#  '반면',
#  '카드',
#  '국회',
#  '총리',
#  '맞',
#  '센터',
#  '건',
#  '실적',
#  '입장',
#  '타',
#  '가량',
#  '기간',
#  '정',
#  '밖에',
#  '보도',
#  '데이터',
#  '19',
#  '유지',
#  '지속',
#  '논의',
#  '프로그램',
#  '대형',
#  '개선',
#  '이달',
#  '방문',
#  '갖추',
#  '체결',
#  '첫',
#  '과정',
#  '후보',
#  '램',
#  '모델',
#  '별',
#  '공개',
#  '현지',
#  '사건',
#  '준비',
#  '달리',
#  '효과',
#  '단계',
#  '으로써',
#  '상대',
#  'B',
#  '찾',
#  '2002',
#  '최고',
#  '내놓',
#  '여부',
#  '당시',
#  '23',
#  '관하',
#  '공격',
#  '조',
#  '환경',
#  '무선',
#  '평균',
#  '서',
#  '상용',
#  '가입자',
#  '또한',
#  '22',
#  '제휴',
#  '사이트',
#  '이유',
#  '주가',
#  '급',
#  '각종',
#  '확산',
#  '국제',
#  '이전',
#  '회담',
#  '지원하',
#  '부품',
#  '외국인',
#  '처리',
#  '각',
#  '회의',
#  '영화',
#  '덧붙이',
#  '대회',
#  '26',
#  '영업',
#  '합의',
#  '웹',
#  '영향',
#  '정통부',
#  '활동',
#  '비용',
#  '내리',
#  '월드컵',
#  '아시아',
#  '대학',
#  '전국',
#  '줄이',
#  '27',
#  '의견',
#  '핵심',
#  '호',
#  '잡',
#  '해결',
#  '빠르',
#  '역시',
#  '거치',
#  '28',
#  '없이',
#  '차원',
#  '이런',
#  '행사',
#  '설치',
#  '남',
#  '러시아',
#  '치',
#  '상승',
#  '선수',
#  '얻',
#  '경쟁력',
#  '보유',
#  '활성화',
#  '늘리',
#  '민주당',
#  '바',
#  '경',
#  '주력',
#  '강',
#  '부시',
#  '오후',
#  '넘',
#  '만나',
#  '이다',
#  '2003',
#  '최종',
#  '확정',
#  '연구',
#  '줄',
#  '비중',
#  '29',
#  '전환',
#  '표준',
#  'DMB',
#  '브랜드',
#  '수사',
#  '마치',
#  '대응',
#  'KTF',
#  '노력',
#  '메모리',
#  '채택',
#  '부담',
#  '전문',
#  'ㄴ데',
#  '독일',
#  '신규',
#  '우선',
#  '모듈',
#  '중요',
#  'PDA',
#  '어도',
#  '관계',
#  '비즈니스',
#  '조치',
#  '작년',
#  '업무',
#  '동시',
#  '대기업',
#  '력',
#  '관련업계',
#  '대만',
#  '오전',
#  'SW',
#  '기관',
#  '참석',
#  '음',
#  '는다',
#  '핵',
#  '모니터',
#  '으면',
#  '테러',
#  '중소기업',
#  '대로',
#  '영국',
#  '감소',
#  '외국',
#  '인증',
#  '60',
#  'A',
#  '제기',
#  '개인',
#  '펼치',
#  '초고속',
#  '맞추',
#  '전문업체',
#  'ㄴ다면서',
#  '개최',
#  '다음',
#  '보고서',
#  '형태',
#  '현',
#  '하락',
#  '거래',
#  '비롯',
#  '달성',
#  '자사',
#  '변화',
#  '돈',
#  '소비자',
#  '2001',
#  '잇따르',
#  '인수',
#  '협의',
#  '상품',
#  '소재',
#  '달하',
#  '무현',
#  '아이',
#  '혐의',
#  '인식',
#  '자금',
#  '아야',
#  '판단',
#  '무선인터넷',
#  '사용자',
#  '의하',
#  '리눅스',
#  '움직임',
#  '경찰',
#  '살',
#  '당초',
#  '교육',
#  '요청',
#  '일반',
#  '보내',
#  '역할',
#  '이동통신',
#  '는지',
#  '시즌',
#  '려는',
#  '물량',
#  '미치',
#  '제안',
#  'CDMA',
#  '제도',
#  'm',
#  '군',
#  '은행',
#  '공장',
#  '자리',
#  '해',
#  '구매',
#  '글로벌',
#  'SI',
#  '반대',
#  '외',
#  '씩',
#  '막',
#  'PDP',
#  '위원장',
#  '새',
#  '라인',
#  '제시',
#  '인사',
#  '신',
#  '정치',
#  '투입',
#  '이동전화',
#  '사이',
#  '수입',
#  '안정',
#  '2005',
#  '고려',
#  '2004',
#  '미군',
#  '낮',
#  '많이',
#  '프랑스',
#  '다음달',
#  '예산',
#  '구체적',
#  '일정',
#  '노트북',
#  '카메라',
#  '인력',
#  '잘',
#  '국산',
#  '차례',
#  '별도',
#  '청와대',
#  '국',
#  '제외',
#  'ㄴ다면',
#  '계기',
#  '제출',
#  '그치',
#  '여성',
#  '주목',
#  '의미',
#  '플랫폼',
#  '포털',
#  '채널',
#  'ㄴ지',
#  '대변인',
#  '망',
#  '이하',
#  '쉽',
#  '회복',
#  '컴퓨터',
#  '부상',
#  '맡',
#  '선',
#  '로서',
#  'C',
#  '건설',
#  '전쟁',
#  '완료',
#  '적극적',
#  '우리나라',
#  '연결',
#  '컨소시엄',
#  '포인트',
#  '여러',
#  '승',
#  '공식',
#  '줄어들',
#  '등록',
#  '전문가들',
#  '산',
#  '시행',
#  '유통',
#  '불법',
#  '단체',
#  '연구원',
#  '속',
#  '중단',
#  '앞두',
#  '리',
#  '쓰',
#  '하며',
#  '추세',
#  '모습',
#  '비',
#  '구현',
#  '법',
#  '이제',
#  '디스플레이',
#  '다르',
#  '발전',
#  '사진',
#  '양산',
#  '31',
#  '폰',
#  'G',
#  '/',
#  '또는',
#  '유엔',
#  '어떤',
#  '최',
#  '세우',
#  '우승',
#  '전문가',
#  '70',
#  '끝나',
#  '자료',
#  '종합',
#  '지분',
#  '이뤄지',
#  '사례',
#  '거두',
#  'ㄹ지',
#  '방법',
#  '감안',
#  '80',
#  'MP',
#  '테스트',
#  '최초',
#  '치열',
#  '출신',
#  '제작',
#  '같이',
#  'HP',
#  '컨설팅',
#  '열린우리당',
#  '메일',
#  '탑재',
#  'DVD',
#  '세계적',
#  '플레이어',
#  '업종',
#  '아파트',
#  'ERP',
#  '사실상',
#  '형성',
#  '맺',
#  '성능',
#  '불구하',
#  '조직',
#  '번째',
#  '대책',
#  '해당',
#  '거의',
#  '대신',
#  '연말',
#  '그렇',
#  '가동',
#  '연계',
#  '참가',
#  '촉구',
#  '자동차',
#  '주식',
#  '성과',
#  '언론',
#  '국방부',
#  '나라',
#  '전달',
#  '연간',
#  '겪',
#  '여기',
#  '주도',
#  '속도',
#  '전반',
#  '담당',
#  '내부',
#  '논란',
#  '진입',
#  '양',
#  '피해',
#  'M',
#  '벤처기업',
#  '육성',
#  '인도',
#  '평',
#  '바꾸',
#  '비롯하',
#  '날',
#  'IBM',
#  '이며',
#  '파',
#  '통과',
#  '영상',
#  '불과하',
#  '?',
#  '반영',
#  '부',
#  '현상',
#  '실제',
#  '개국',
#  '연속',
#  '조정',
#  '공정',
#  'TFT',
#  '모르',
#  '통신사업자',
#  '수주',
#  '99',
#  '장기',
#  '대규모',
#  '모으',
#  '대폭',
#  '전세계',
#  '반응',
#  '훈련',
#  '금융',
#  '채',
#  '바탕',
#  '학교',
#  '매각',
#  '위성',
#  '전화',
#  '위치',
#  '풀이',
#  '이동',
#  '선거',
#  '세트',
#  '착수',
#  '인프라',
#  '사람들',
#  '멀티미디어',
#  '점유율',
#  '과거',
#  '이미지',
#  '입',
#  '인정',
#  '하루',
#  '체제',
#  '권',
#  '니',
#  '시험',
#  '케이블',
#  '지상파',
#  '능력',
#  '강하',
#  '분위기',
#  '보급',
#  '부족',
#  '내다보',
#  '의사',
#  '스럽',
#  '국내외',
#  '정하',
#  '발언',
#  '힘들',
#  '경영',
#  '보고',
#  '상당',
#  '표준화',
#  '300',
#  '정상',
#  '시기',
#  '신청',
#  '증시',
#  '제조업체',
#  '컬러',
#  '성',
#  '기회',
#  '정보통신부',
#  '길',
#  '과제',
#  '어떻',
#  '힘',
#  '인기',
#  '마무리',
#  '전략적',
#  '어느',
#  '수립',
#  '홍',
#  '90',
#  '부처',
#  '의혹',
#  '작',
#  '바로',
#  '께',
#  '야',
#  '몇',
#  '마켓',
#  '싶',
#  '부분',
#  'R',
#  ...]

# %%
## check word embed result
word = '버스'
print(model.wv[word])
print('size of vector: ', len(model.wv[word]))
# Out:
# [-0.1685909  -0.06815929  0.03862754 -0.17013025 -0.0222107  -0.32134584
#   0.32902363  0.02374835 -0.32800677 -0.5159291  -0.03338749  0.22155814
#  -0.7748226   0.10288942  0.01950315  0.12780008  0.2330913   0.37870157
#  -0.06138415 -0.42132545 -0.3672338   0.09775122  0.22589192 -0.17918798
#   0.34277806 -0.3893849  -0.46086147 -0.17517492 -0.44161347 -0.08979039
#  -0.60346144  0.21198706 -0.02217958 -0.0661274  -0.10122002 -0.05852121
#  -0.18313754  0.07583261  0.14024098  0.7634658   0.2056343   0.15760174
#   0.41918263  0.508057    0.6573746   0.01041878  0.2764879  -0.115475
#  -0.62231994 -0.20625061 -0.03133462 -0.20136891 -0.0603966  -0.12205875
#  -0.3280499   0.5147516  -0.30284822 -0.37873787  0.1165148  -0.11643907
#   0.22712985  0.01339927  0.11130055  0.24697241  0.11539216  0.46687412
#   0.15046936  0.2494117   0.3704534   0.11955588 -0.08151569 -0.02378023
#   0.23902106 -0.36102486 -0.10081082 -0.03202547 -0.20903397  0.36197385
#  -0.20855834 -0.37764156  0.2909458  -0.11058491 -0.19837153 -0.08761185
#  -0.19970779 -0.2205983   0.07976125 -0.18440974  0.19394027 -0.05397236
#   0.07029818 -0.36425802 -0.17505908 -0.09487887  0.07956205  0.17827864
#  -0.15323836 -0.4393289   0.09067572 -0.03275201 -0.05184664  0.30649248
#   0.06384581 -0.22982965  0.351204   -0.32230574 -0.20601252  0.17896268
#   0.12126419  0.1247086   0.1776215   0.12334214 -0.06866053 -0.34942
#   0.21203135 -0.08643363  0.03928848  0.10809563  0.01256341  0.16735324
#  -0.17276023 -0.14982682  0.09694289 -0.064557    0.07341983 -0.17617927
#  -0.00401324 -0.29218805  0.32811603  0.00108197  0.11880441  0.1322128
#  -0.12495104 -0.05471558 -0.14969246 -0.02000697 -0.17280735  0.23070909
#  -0.11296996 -0.09197827 -0.08072458  0.07694404 -0.36448598 -0.51306146
#   0.5136357  -0.05972006  0.36647585 -0.00305962  0.5798779   0.00272303
#   0.18857346  0.25242522  0.05490888 -0.2733234  -0.08494008 -0.18999644
#   0.09144644  0.23758459  0.33494368  0.13653438  0.01692947 -0.18533477
#  -0.35656533  0.04799251 -0.12863372  0.3846041  -0.16821711 -0.04633825
#   0.42026883 -0.01527444  0.20315091 -0.34165016 -0.21567349 -0.16226457
#  -0.0680415  -0.15473907  0.12381026  0.03984537 -0.13432963  0.15750502
#  -0.05547654  0.3322636   0.6089532   0.26895678 -0.6318009  -0.05096606
#   0.21183509  0.30054906 -0.19304022 -0.21502249  0.11062764 -0.14057115
#   0.3213179   0.2299206  -0.03160316 -0.64110315  0.1785497   0.09223969
#  -0.10673963  0.23239791 -0.0458664   0.31799865  0.06748931  0.19919212
#  -0.33361787 -0.14399137 -0.0329904   0.29681003  0.58083284 -0.2419683
#  -0.00332796 -0.45689186  0.5516446   0.12260277  0.00266454  0.07718232
#   0.24001203  0.1356159   0.03390045 -0.1272109   0.01011793 -0.3026312
#  -0.01640375  0.54039615  0.21885319  0.23724289  0.12145941  0.14601281
#   0.02899314 -0.20338196  0.27725485  0.05258142 -0.17300676 -0.25840136
#   0.0567007   0.31131372  0.10544557  0.11185159 -0.29993108  0.26762778
#  -0.25283977 -0.23071282 -0.6584341  -0.04687474 -0.07763369 -0.26324892
#   0.30919224  0.04356796  0.06137596  0.11493886 -0.32969484 -0.04723041
#   0.25280282 -0.35877338  0.32441697 -0.07115158  0.1187418   0.28046203
#  -0.0472091   0.421968   -0.24093738  0.4174331   0.08974891 -0.11279384
#  -0.3548794  -0.20271753  0.02082899  0.02292686 -0.20828328 -0.45142677
#  -0.18735638 -0.14790145  0.70116985  0.11967588  0.03444984  0.24844466
#   0.33110252  0.1706847  -0.07804718  0.20255695 -0.31939968 -0.33244476
#   0.04981757  0.11055805  0.62595344  0.22190522  0.19907969  0.23830435
#  -0.04947586 -0.04781953  0.06777821 -0.19165732  0.39730442  0.10262661
#  -0.32495964 -0.45739147 -0.42733988 -0.4764966   0.06901068  0.28899133]
# size of vector:  300

# %% [markdown]
# # Step4: Get word similarity

# %%
#word1 = '한국'
#word2 = '북한'
print ("Caculate the similarity between word 1 and word2")
word1 = input("word1: ")
word2 = input("word2: ")

# check the words are in the vocabulary
no_problem = True
vocab = model.wv.index2word

if word1 not in vocab:
	print ('the word ' + word1 + ' is not in the vocabulary')
	no_problem = False

if word2 not in vocab:
	print ('the word ' + word2 + ' is not in the vocabulary')
	no_problem = False

if no_problem:
	similarity = model.wv.similarity(word1, word2)
	print ('the similarity between ' + word1 + ' and ' + word2 + ' : ', similarity)
# Out:
# Caculate the similarity between word 1 and word2
# word1: 한국
# word2: 중국
# the similarity between 한국 and 중국 :  0.3785267

# %% [markdown]
# # Step5: Find mismatch word

# %%
#words = '소프트웨어 네트워크 프로그램 가방'
print("Find mismatched word in the words")
text = input("text(words): ")
words = text.split()

# check the words are in the vocabulary
no_problem = True
vocab = model.wv.index2word

for word in words:
	if word not in vocab:
		print('the word ' + word + ' is not in the vocabulary')
		no_problem = False
		break;

if no_problem:
	mismatched = model.wv.doesnt_match(words)
	print ('the mismatch word between ' + text +' is', mismatched)
# Out:
# Find mismatched word in the words
# text(words): 소프트웨어 하드웨어
# the mismatch word between 소프트웨어 하드웨어 is 하드웨어
# /home/piai/anaconda3/envs/AIBD/lib/python3.8/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %% [markdown]
# # Step 6. Find the top-N most similar words

# %%
print("Print the most similar words")
word = input("word: ")

no_problem = True
vocab = model.wv.index2word

if word not in vocab:
	print ('the word ' + word + ' is not in the vocabulary')
	no_problem = False

if no_problem:
    print(model.wv.most_similar(positive=[word]))
# Out:
# Print the most similar words
# word: 인간
# [('동물', 0.617953896522522), ('배아', 0.6104809641838074), ('생쥐', 0.5970973968505859), ('존엄성', 0.5852876901626587), ('본성', 0.5809779167175293), ('인류', 0.5760883092880249), ('생명체', 0.5717364549636841), ('유기체', 0.5703120827674866), ('핵이식', 0.5635316371917725), ('욕망', 0.561828076839447)]

# %% [markdown]
# # Step 7: Vector calculation

# %%
#word_a = '한국'
#word_b = '아시아'
#word_c = '유럽'
print('Find the most similar word with the result of [ a - b + c ]')
word_a = input("a: ")
word_b = input("b: ")
word_c = input("c: ")

# check the words are in the vocabulary
no_problem = True
vocab = model.wv.index2word

if word_a not in vocab:
	print ('the word ' + word_a + ' is not in the vocabulary')
	no_problem = False

if word_b not in vocab:
	print ('the word ' + word_b + ' is not in the vocabulary')
	no_problem = False

if word_c not in vocab:
	print ('the word ' + word_c + ' is not in the vocabulary')
	no_problem = False

if no_problem:
	mostsimilar = model.wv.most_similar(positive=[word_a, word_c], negative=[word_b], topn=5)
	print ('most similar word of ' + word_a + ' - ' + word_b + ' + ' + word_c + ' is', mostsimilar[0][0], mostsimilar[1][0], mostsimilar[2][0])
# Out:
# Find the most similar word with the result of [ a - b + c ]
# a: 독도
# b: 한국
# c: 일본
# most similar word of 독도 - 한국 + 일본 is 다케시마 영유권 울릉도
